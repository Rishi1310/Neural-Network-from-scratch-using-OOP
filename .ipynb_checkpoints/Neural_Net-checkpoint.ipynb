# %%
import numpy as np

class Neural_Net:
    def __init__(self, layers):
        self.n_layers=len(layers)
        self.inputs=None
        self.outputs=None
        self.Layers=[]
        self.Weights=[]
        self.WGrads = []
        self.Bias=[]
        self.BGrads = []
        self.layers=layers
        self.learning_rate = 0
        self.n_inps = 0
        self.inputs_val = None
        self.outputs_val = None
        
    class Layer:
        def __init__(self, n_neurons):
            self.neurons = []
            self.n_neurons = n_neurons
            for i in range(self.n_neurons):
                self.neurons.append(Neuron())

        class Neuron:
            def __init__(self):
                self.type = 'relu'
                self.fp = 0
                self.z = 0
                self.W = []
                self.b = 0
                self.ac_1 = []
                self.dz=0

            def _weighted_sum(self):
                summ = 0
                for i in range(len(self.ac_1)):
                    summ+=self.ac_1[i]*self.W[i]
                return summ + self.b

            def _activation_fn(self):
                if(self.type=='relu'):
                    if self.z > 0:
                        return self.z
                    return 0
                elif(self.type=='sigm'):
                    return 1/(1+np.exp(-self.z))
                else:
                    raise Exception('Invalid Activation Function')

            def forward_propagate(self,inp,weights,bias,choice='relu'):
                assert(len(inp)==len(weights))
                self.type=choice
                self.ac_1 = inp
                self.W = weights
                self.b = bias
                self.z = self._weighted_sum()
                self.fp = self._activation_fn()
                return self.fp

            def _back_activation_fn(self):
                if(self.type=='relu'):
                    if(self.z<0):
                        return 0
                    else:
                        return self.dac
                elif(self.type=='sigm'):
                    return self.dac*self.fp*(1-self.fp)
                else:
                    raise Exception("Invalid activation function")

            def back_propagate(self,dac):
                self.dac = dac
                self.dz = self._back_activation_fn()
                m = len(self.ac_1)
                dw = np.array(self.ac_1)*self.dz
                db = self.dz
                dac_1 = np.array(self.W)*self.dz
                return dw,db,dac_1
            

        def forward_propagate(self, inputs, weights,bias,choice='relu'):
            output = []
            for i in range(self.n_neurons):
                output.append(self.neurons[i].forward_propagate(inputs,weights[i],bias[i],choice))
            return output

        def back_propagate(self,dacs):
            dacs=np.array(dacs.mean(axis=0))
            dws = []
            dbs = []
            dac_1s = []
            for i in range(dacs.shape[0]):
                temp1,temp2,temp3 = self.neurons[i].back_propagate(dacs[i])
                dws.append(temp1)
                dbs.append(temp2)
                dac_1s.append(temp3)
            return np.array(dws),np.array(dbs),np.array(dac_1s)
        
        
    def _showWandB(self):
        print('Weights:',self.Weights)
        print('Bias:',self.Bias)
        
    def _showGWandBG(self):
        print('WGrads:',self.WGrads)
        print('BGrads:',self.BGrads)
        
    def _initialize(self):
        for i in range(self.n_layers):
            self.Layers.append(Layer(self.layers[i]))
            if i==0:
                self.Weights.append(np.random.randn(self.layers[i],len(self.inputs[0])))#####
                self.Bias.append(np.random.randn(self.layers[0]))
            else:
                self.Weights.append(np.random.randn(self.layers[i],self.layers[i-1]))
                self.Bias.append(np.random.randn(self.layers[i]))
        self.Layers.append(Layer(1))
        self.Weights.append(np.random.randn(1,self.layers[self.n_layers-1]))
        self.Bias.append(np.random.randn(1))
                
    def _forward_propagate(self,temp):
        for i in range(len(self.Layers)):
            if i==0:
                temp = self.Layers[i].forward_propagate(temp,self.Weights[i],self.Bias[i],'relu')
            elif i==self.n_layers:
                temp = self.Layers[i].forward_propagate(temp,self.Weights[i],self.Bias[i],choice='sigm')
            else:
                temp = self.Layers[i].forward_propagate(temp,self.Weights[i],self.Bias[i],'relu')
        return temp
    
    def _compute_cost(self,pred,act,cost_type = 'crs_ent'):
        temp_out = np.array(pred)
        act=np.array(act)
        act = np.expand_dims(act,axis=0)
        m = act.shape[0]
        if(cost_type == 'mse'):
            cost = (1/(2*m))*(np.array(temp_out)-np.array(act))**2
            cost_der = np.array(temp_out)-np.array(act)
        elif(cost_type == 'crs_ent'):
#             print("m is ", m)
            if(temp_out==1):
                temp_out-=0.00001
            elif(temp_out==0):
                temp_out+=0.00001
            cost = (-1 / m) * (np.multiply(act, np.log(temp_out)) + np.multiply(1 - act, np.log(1 - temp_out)))
            cost_der =  (-1/m)* (np.divide(act, temp_out) - np.divide(1 - act, 1 - temp_out))
        else:
            raise Exception('Invalid cost function given.')
        return cost,cost_der
    
    def _back_propagate(self,cost_der):
        temp3 = np.array(cost_der)
        temp3 = np.expand_dims(temp3,axis=1)
        Wg = []
        Bg = []
        for i in reversed(range(len(self.Layers))):
            temp1, temp2, temp3 = self.Layers[i].back_propagate(temp3)
            Wg.insert(0,temp1)
            Bg.insert(0,temp2)
        return Wg,Bg
                
    def _update_weights(self):
        for i in range(len(self.Layers)):
            self.Weights[i] = self.Weights[i] - self.learning_rate * self.WGrads[i]
            self.Bias[i] = self.Bias[i] - self.learning_rate * self.BGrads[i]
     
    def train(self,inps,outs,inp_val,out_val,epochs=50,learning_rate = 0.03,printCost=False,printEvery = 10, printFrom = 0):
        self.inputs = inps
        self.outputs = outs
        self.inputs_val = inp_val
        self.outputs_val = out_val
        self.learning_rate = learning_rate
        self._initialize()
        cost_av = 0
        cost_der_av = 0
        self.n_inps = self.inputs.shape[0]
        costs = []
        trn_acc = []
        tst_acc = []
        WGtemp = []
        BGtemp = []
        xaxis = []
        for i in range(epochs):
            for j in range(len(self.inputs)):
                pred = self._forward_propagate(self.inputs[j])
#                 print(pred,end=" ")
                cost,cost_der = self._compute_cost(pred,self.outputs[j])
                WGtemp,BGtemp=self._back_propagate(cost_der)
                cost_av+=cost
                cost_der_av+=cost_der
                if(j==0):
                    self.WGrads = WGtemp
                    self.BGrads = BGtemp
                else:
                    for k in range(len(self.Layers)):
                        self.WGrads[k]=self.WGrads[k]+WGtemp[k]
                        self.BGrads[k]=self.BGrads[k]+BGtemp[k]
            for j in range(len(self.Layers)):
                self.WGrads[j]=self.WGrads[j]/self.n_inps
                self.BGrads[j]=self.BGrads[j]/self.n_inps
            cost_av/=self.n_inps
            cost_der_av/=self.n_inps
            if(printCost and i%printEvery==0 and i>=printFrom):# and i!=0 and i>10):
                print("Epoch %d/%d,"%(i+1,epochs),end=" ")
                print("Cost = %f,"%(cost_av),end=" ")
                _,acc1 = self.predict_classes(self.inputs,self.outputs)
                _,acc2 = self.predict_classes(self.inputs_val, self.outputs_val)
                print("Training Accuracy = %f, Validation Accuracy = %f"%(acc1,acc2))
                trn_acc.append(acc1)
                tst_acc.append(acc2)
                xaxis.append(i)
                costs.append(cost_av[0])
#             self._showGWandBG()
            self._update_weights()
        print("Epoch %d/%d,"%(epochs,epochs),end=" ")
        print("Cost = %f,"%(cost_av),end=" ")
        _,acc1 = self.predict_classes(self.inputs,self.outputs)
        _,acc2 = self.predict_classes(self.inputs_val, self.outputs_val)
        print("Training Accuracy = %f, Validation Accuracy = %f"%(acc1,acc2))
        
        plt.subplot(2, 1, 1)
        plt.plot(np.squeeze(costs))
        plt.ylabel('Cost')
        plt.xlabel('Epochs')
        plt.title("Learning rate =" + str(self.learning_rate))
        
        plt.subplot(2, 1, 2)
        plt.plot(xaxis,trn_acc)
        plt.plot(xaxis,tst_acc)
        plt.ylabel('Accuracy')
        plt.xlabel('Epochs')
        plt.legend(['Train Acc', 'Test Acc'])
        plt.title("Training and Test Acuuracies")
        
        plt.show()
        
        return costs
#         self._showWandB()
#         self._showGWandBG()

    def predict(self,p):
        preds = []
        for temp in p:
            for i in range(len(self.Layers)):
                if i==0:
                    temp = self.Layers[i].forward_propagate(temp,self.Weights[i],self.Bias[i],'relu')
                elif i==self.n_layers:
                    temp = self.Layers[i].forward_propagate(temp,self.Weights[i],self.Bias[i],choice='sigm')
                else:
                    temp = self.Layers[i].forward_propagate(temp,self.Weights[i],self.Bias[i],'relu')
            preds.append(temp)
        return preds
    
    def predict_classes(self,p,q):
        preds = np.array(self.predict(p))
        preds[preds>0.5]=1
        preds[preds<=0.5]=0
        preds = np.squeeze(preds)
        acc = np.sum((preds == q)/p.shape[0])
        return preds,acc

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

data = pd.read_csv('./diabetes.csv')

inputs = data.drop('Outcome', axis = 1)
inputs = np.array(inputs)

from sklearn.preprocessing import StandardScaler, MinMaxScaler
sc = MinMaxScaler()
inputs = sc.fit_transform(inputs)
outputs = data['Outcome'].as_matrix()

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(inputs, outputs, test_size=0.10, random_state=42)

plt.rcParams['figure.figsize'] = (15.0, 12.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
# Out:
# /home/rishi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   app.launch_new_instance()

# %%
np.random.seed(10)
net = Neural_Net([10,5])
costs = net.train(X_train,y_train,X_test,y_test,epochs=400,learning_rate=0.2,printCost=True,printEvery=1, printFrom = 10)
# Out:
# Epoch 11/400, Cost = 0.682927, Training Accuracy = 0.697540, Validation Accuracy = 0.701299
# Epoch 12/400, Cost = 0.676974, Training Accuracy = 0.704776, Validation Accuracy = 0.688312
# Epoch 13/400, Cost = 0.671505, Training Accuracy = 0.706223, Validation Accuracy = 0.688312
# Epoch 14/400, Cost = 0.666443, Training Accuracy = 0.714906, Validation Accuracy = 0.688312
# Epoch 15/400, Cost = 0.661745, Training Accuracy = 0.722142, Validation Accuracy = 0.714286
# Epoch 16/400, Cost = 0.657380, Training Accuracy = 0.719247, Validation Accuracy = 0.727273
# Epoch 17/400, Cost = 0.653305, Training Accuracy = 0.720695, Validation Accuracy = 0.740260
# Epoch 18/400, Cost = 0.649482, Training Accuracy = 0.714906, Validation Accuracy = 0.727273
# Epoch 19/400, Cost = 0.645897, Training Accuracy = 0.717800, Validation Accuracy = 0.727273
# Epoch 20/400, Cost = 0.642526, Training Accuracy = 0.720695, Validation Accuracy = 0.727273
# Epoch 21/400, Cost = 0.639317, Training Accuracy = 0.723589, Validation Accuracy = 0.727273
# Epoch 22/400, Cost = 0.636244, Training Accuracy = 0.725036, Validation Accuracy = 0.727273
# Epoch 23/400, Cost = 0.633352, Training Accuracy = 0.726483, Validation Accuracy = 0.727273
# Epoch 24/400, Cost = 0.630638, Training Accuracy = 0.722142, Validation Accuracy = 0.727273
# Epoch 25/400, Cost = 0.628069, Training Accuracy = 0.720695, Validation Accuracy = 0.740260
# Epoch 26/400, Cost = 0.625600, Training Accuracy = 0.722142, Validation Accuracy = 0.740260
# Epoch 27/400, Cost = 0.623236, Training Accuracy = 0.723589, Validation Accuracy = 0.740260
# Epoch 28/400, Cost = 0.620963, Training Accuracy = 0.723589, Validation Accuracy = 0.740260
# Epoch 29/400, Cost = 0.618772, Training Accuracy = 0.722142, Validation Accuracy = 0.740260
# Epoch 30/400, Cost = 0.616670, Training Accuracy = 0.722142, Validation Accuracy = 0.740260
# Epoch 31/400, Cost = 0.614655, Training Accuracy = 0.723589, Validation Accuracy = 0.740260
# Epoch 32/400, Cost = 0.612713, Training Accuracy = 0.723589, Validation Accuracy = 0.740260
# Epoch 33/400, Cost = 0.610855, Training Accuracy = 0.725036, Validation Accuracy = 0.740260
# Epoch 34/400, Cost = 0.609062, Training Accuracy = 0.726483, Validation Accuracy = 0.740260
# Epoch 35/400, Cost = 0.607316, Training Accuracy = 0.726483, Validation Accuracy = 0.740260
# Epoch 36/400, Cost = 0.605626, Training Accuracy = 0.726483, Validation Accuracy = 0.727273
# Epoch 37/400, Cost = 0.603980, Training Accuracy = 0.726483, Validation Accuracy = 0.727273
# Epoch 38/400, Cost = 0.602384, Training Accuracy = 0.729378, Validation Accuracy = 0.727273
# Epoch 39/400, Cost = 0.600836, Training Accuracy = 0.726483, Validation Accuracy = 0.727273
# Epoch 40/400, Cost = 0.599351, Training Accuracy = 0.727931, Validation Accuracy = 0.727273
# Epoch 41/400, Cost = 0.597915, Training Accuracy = 0.729378, Validation Accuracy = 0.727273
# Epoch 42/400, Cost = 0.596524, Training Accuracy = 0.729378, Validation Accuracy = 0.727273
# Epoch 43/400, Cost = 0.595171, Training Accuracy = 0.730825, Validation Accuracy = 0.727273
# Epoch 44/400, Cost = 0.593856, Training Accuracy = 0.730825, Validation Accuracy = 0.727273
# Epoch 45/400, Cost = 0.592580, Training Accuracy = 0.732272, Validation Accuracy = 0.727273
# Epoch 46/400, Cost = 0.591338, Training Accuracy = 0.730825, Validation Accuracy = 0.727273
# Epoch 47/400, Cost = 0.590133, Training Accuracy = 0.730825, Validation Accuracy = 0.727273
# Epoch 48/400, Cost = 0.588958, Training Accuracy = 0.730825, Validation Accuracy = 0.727273
# Epoch 49/400, Cost = 0.587810, Training Accuracy = 0.730825, Validation Accuracy = 0.727273
# Epoch 50/400, Cost = 0.586694, Training Accuracy = 0.729378, Validation Accuracy = 0.727273
# Epoch 51/400, Cost = 0.585606, Training Accuracy = 0.729378, Validation Accuracy = 0.727273
# Epoch 52/400, Cost = 0.584544, Training Accuracy = 0.730825, Validation Accuracy = 0.727273
# Epoch 53/400, Cost = 0.583509, Training Accuracy = 0.730825, Validation Accuracy = 0.727273
# Epoch 54/400, Cost = 0.582499, Training Accuracy = 0.730825, Validation Accuracy = 0.727273
# Epoch 55/400, Cost = 0.581514, Training Accuracy = 0.730825, Validation Accuracy = 0.727273
# Epoch 56/400, Cost = 0.580551, Training Accuracy = 0.729378, Validation Accuracy = 0.727273
# Epoch 57/400, Cost = 0.579610, Training Accuracy = 0.730825, Validation Accuracy = 0.727273
# Epoch 58/400, Cost = 0.578691, Training Accuracy = 0.733719, Validation Accuracy = 0.727273
# Epoch 59/400, Cost = 0.577792, Training Accuracy = 0.733719, Validation Accuracy = 0.727273
# Epoch 60/400, Cost = 0.576914, Training Accuracy = 0.733719, Validation Accuracy = 0.727273
# Epoch 61/400, Cost = 0.576058, Training Accuracy = 0.733719, Validation Accuracy = 0.727273
# Epoch 62/400, Cost = 0.575222, Training Accuracy = 0.735166, Validation Accuracy = 0.727273
# Epoch 63/400, Cost = 0.574405, Training Accuracy = 0.736614, Validation Accuracy = 0.727273
# Epoch 64/400, Cost = 0.573606, Training Accuracy = 0.735166, Validation Accuracy = 0.727273
# Epoch 65/400, Cost = 0.572824, Training Accuracy = 0.735166, Validation Accuracy = 0.727273
# Epoch 66/400, Cost = 0.572059, Training Accuracy = 0.735166, Validation Accuracy = 0.727273
# Epoch 67/400, Cost = 0.571312, Training Accuracy = 0.736614, Validation Accuracy = 0.727273
# Epoch 68/400, Cost = 0.570582, Training Accuracy = 0.735166, Validation Accuracy = 0.727273
# Epoch 69/400, Cost = 0.569870, Training Accuracy = 0.735166, Validation Accuracy = 0.727273
# Epoch 70/400, Cost = 0.569173, Training Accuracy = 0.733719, Validation Accuracy = 0.727273
# Epoch 71/400, Cost = 0.568492, Training Accuracy = 0.733719, Validation Accuracy = 0.727273
# Epoch 72/400, Cost = 0.567825, Training Accuracy = 0.736614, Validation Accuracy = 0.727273
# Epoch 73/400, Cost = 0.567173, Training Accuracy = 0.736614, Validation Accuracy = 0.727273
# Epoch 74/400, Cost = 0.566534, Training Accuracy = 0.736614, Validation Accuracy = 0.727273
# Epoch 75/400, Cost = 0.565908, Training Accuracy = 0.736614, Validation Accuracy = 0.727273
# Epoch 76/400, Cost = 0.565296, Training Accuracy = 0.736614, Validation Accuracy = 0.727273
# Epoch 77/400, Cost = 0.564697, Training Accuracy = 0.736614, Validation Accuracy = 0.727273
# Epoch 78/400, Cost = 0.564110, Training Accuracy = 0.736614, Validation Accuracy = 0.727273
# Epoch 79/400, Cost = 0.563535, Training Accuracy = 0.736614, Validation Accuracy = 0.727273
# Epoch 80/400, Cost = 0.562972, Training Accuracy = 0.735166, Validation Accuracy = 0.727273
# Epoch 81/400, Cost = 0.562420, Training Accuracy = 0.735166, Validation Accuracy = 0.727273
# Epoch 82/400, Cost = 0.561880, Training Accuracy = 0.738061, Validation Accuracy = 0.727273
# Epoch 83/400, Cost = 0.561351, Training Accuracy = 0.738061, Validation Accuracy = 0.727273
# Epoch 84/400, Cost = 0.560833, Training Accuracy = 0.738061, Validation Accuracy = 0.727273
# Epoch 85/400, Cost = 0.560325, Training Accuracy = 0.738061, Validation Accuracy = 0.727273
# Epoch 86/400, Cost = 0.559826, Training Accuracy = 0.738061, Validation Accuracy = 0.727273
# Epoch 87/400, Cost = 0.559331, Training Accuracy = 0.735166, Validation Accuracy = 0.727273
# Epoch 88/400, Cost = 0.558847, Training Accuracy = 0.735166, Validation Accuracy = 0.727273
# Epoch 89/400, Cost = 0.558373, Training Accuracy = 0.735166, Validation Accuracy = 0.727273
# Epoch 90/400, Cost = 0.557907, Training Accuracy = 0.733719, Validation Accuracy = 0.727273
# Epoch 91/400, Cost = 0.557450, Training Accuracy = 0.736614, Validation Accuracy = 0.727273
# Epoch 92/400, Cost = 0.557002, Training Accuracy = 0.736614, Validation Accuracy = 0.727273
# Epoch 93/400, Cost = 0.556561, Training Accuracy = 0.736614, Validation Accuracy = 0.727273
# Epoch 94/400, Cost = 0.556127, Training Accuracy = 0.739508, Validation Accuracy = 0.727273
# Epoch 95/400, Cost = 0.555698, Training Accuracy = 0.735166, Validation Accuracy = 0.727273
# Epoch 96/400, Cost = 0.555278, Training Accuracy = 0.736614, Validation Accuracy = 0.727273
# Epoch 97/400, Cost = 0.554866, Training Accuracy = 0.738061, Validation Accuracy = 0.727273
# Epoch 98/400, Cost = 0.554460, Training Accuracy = 0.738061, Validation Accuracy = 0.727273
# Epoch 99/400, Cost = 0.554061, Training Accuracy = 0.739508, Validation Accuracy = 0.727273
# Epoch 100/400, Cost = 0.553668, Training Accuracy = 0.739508, Validation Accuracy = 0.727273
# Epoch 101/400, Cost = 0.553282, Training Accuracy = 0.739508, Validation Accuracy = 0.727273
# Epoch 102/400, Cost = 0.552903, Training Accuracy = 0.739508, Validation Accuracy = 0.727273
# Epoch 103/400, Cost = 0.552531, Training Accuracy = 0.740955, Validation Accuracy = 0.727273
# Epoch 104/400, Cost = 0.552166, Training Accuracy = 0.740955, Validation Accuracy = 0.727273
# Epoch 105/400, Cost = 0.551802, Training Accuracy = 0.740955, Validation Accuracy = 0.727273
# Epoch 106/400, Cost = 0.551433, Training Accuracy = 0.739508, Validation Accuracy = 0.727273
# Epoch 107/400, Cost = 0.551067, Training Accuracy = 0.738061, Validation Accuracy = 0.727273
# Epoch 108/400, Cost = 0.550709, Training Accuracy = 0.738061, Validation Accuracy = 0.727273
# Epoch 109/400, Cost = 0.550357, Training Accuracy = 0.739508, Validation Accuracy = 0.727273
# Epoch 110/400, Cost = 0.550011, Training Accuracy = 0.738061, Validation Accuracy = 0.727273
# Epoch 111/400, Cost = 0.549671, Training Accuracy = 0.739508, Validation Accuracy = 0.727273
# Epoch 112/400, Cost = 0.549337, Training Accuracy = 0.739508, Validation Accuracy = 0.727273
# Epoch 113/400, Cost = 0.549007, Training Accuracy = 0.739508, Validation Accuracy = 0.727273
# Epoch 114/400, Cost = 0.548681, Training Accuracy = 0.739508, Validation Accuracy = 0.727273
# Epoch 115/400, Cost = 0.548360, Training Accuracy = 0.739508, Validation Accuracy = 0.727273
# Epoch 116/400, Cost = 0.548040, Training Accuracy = 0.739508, Validation Accuracy = 0.727273
# Epoch 117/400, Cost = 0.547713, Training Accuracy = 0.743849, Validation Accuracy = 0.727273
# Epoch 118/400, Cost = 0.547391, Training Accuracy = 0.743849, Validation Accuracy = 0.727273
# Epoch 119/400, Cost = 0.547074, Training Accuracy = 0.745297, Validation Accuracy = 0.727273
# Epoch 120/400, Cost = 0.546761, Training Accuracy = 0.745297, Validation Accuracy = 0.727273
# Epoch 121/400, Cost = 0.546453, Training Accuracy = 0.745297, Validation Accuracy = 0.727273
# Epoch 122/400, Cost = 0.546148, Training Accuracy = 0.745297, Validation Accuracy = 0.727273
# Epoch 123/400, Cost = 0.545848, Training Accuracy = 0.745297, Validation Accuracy = 0.727273
# Epoch 124/400, Cost = 0.545552, Training Accuracy = 0.745297, Validation Accuracy = 0.727273
# Epoch 125/400, Cost = 0.545261, Training Accuracy = 0.746744, Validation Accuracy = 0.727273
# Epoch 126/400, Cost = 0.544975, Training Accuracy = 0.745297, Validation Accuracy = 0.727273
# Epoch 127/400, Cost = 0.544693, Training Accuracy = 0.745297, Validation Accuracy = 0.727273
# Epoch 128/400, Cost = 0.544413, Training Accuracy = 0.745297, Validation Accuracy = 0.727273
# Epoch 129/400, Cost = 0.544137, Training Accuracy = 0.742402, Validation Accuracy = 0.727273
# Epoch 130/400, Cost = 0.543865, Training Accuracy = 0.743849, Validation Accuracy = 0.727273
# Epoch 131/400, Cost = 0.543595, Training Accuracy = 0.743849, Validation Accuracy = 0.727273
# Epoch 132/400, Cost = 0.543328, Training Accuracy = 0.743849, Validation Accuracy = 0.727273
# Epoch 133/400, Cost = 0.543053, Training Accuracy = 0.745297, Validation Accuracy = 0.727273
# Epoch 134/400, Cost = 0.542784, Training Accuracy = 0.745297, Validation Accuracy = 0.727273
# Epoch 135/400, Cost = 0.542518, Training Accuracy = 0.745297, Validation Accuracy = 0.727273
# Epoch 136/400, Cost = 0.542257, Training Accuracy = 0.745297, Validation Accuracy = 0.727273
# Epoch 137/400, Cost = 0.541998, Training Accuracy = 0.745297, Validation Accuracy = 0.727273
# Epoch 138/400, Cost = 0.541742, Training Accuracy = 0.745297, Validation Accuracy = 0.727273
# Epoch 139/400, Cost = 0.541485, Training Accuracy = 0.746744, Validation Accuracy = 0.727273
# Epoch 140/400, Cost = 0.541206, Training Accuracy = 0.746744, Validation Accuracy = 0.727273
# Epoch 141/400, Cost = 0.540941, Training Accuracy = 0.746744, Validation Accuracy = 0.727273
# Epoch 142/400, Cost = 0.540678, Training Accuracy = 0.745297, Validation Accuracy = 0.727273
# Epoch 143/400, Cost = 0.540404, Training Accuracy = 0.745297, Validation Accuracy = 0.740260
# Epoch 144/400, Cost = 0.540135, Training Accuracy = 0.745297, Validation Accuracy = 0.740260
# Epoch 145/400, Cost = 0.539870, Training Accuracy = 0.743849, Validation Accuracy = 0.740260
# Epoch 146/400, Cost = 0.539607, Training Accuracy = 0.743849, Validation Accuracy = 0.740260
# Epoch 147/400, Cost = 0.539348, Training Accuracy = 0.743849, Validation Accuracy = 0.740260
# Epoch 148/400, Cost = 0.539092, Training Accuracy = 0.743849, Validation Accuracy = 0.727273
# Epoch 149/400, Cost = 0.538839, Training Accuracy = 0.743849, Validation Accuracy = 0.727273
# Epoch 150/400, Cost = 0.538589, Training Accuracy = 0.743849, Validation Accuracy = 0.727273
# Epoch 151/400, Cost = 0.538340, Training Accuracy = 0.743849, Validation Accuracy = 0.727273
# Epoch 152/400, Cost = 0.538093, Training Accuracy = 0.743849, Validation Accuracy = 0.727273
# Epoch 153/400, Cost = 0.537849, Training Accuracy = 0.745297, Validation Accuracy = 0.727273
# Epoch 154/400, Cost = 0.537605, Training Accuracy = 0.743849, Validation Accuracy = 0.727273
# Epoch 155/400, Cost = 0.537363, Training Accuracy = 0.743849, Validation Accuracy = 0.727273
# Epoch 156/400, Cost = 0.537124, Training Accuracy = 0.743849, Validation Accuracy = 0.727273
# Epoch 157/400, Cost = 0.536887, Training Accuracy = 0.743849, Validation Accuracy = 0.714286
# Epoch 158/400, Cost = 0.536652, Training Accuracy = 0.743849, Validation Accuracy = 0.714286
# Epoch 159/400, Cost = 0.536421, Training Accuracy = 0.743849, Validation Accuracy = 0.714286
# Epoch 160/400, Cost = 0.536191, Training Accuracy = 0.743849, Validation Accuracy = 0.714286
# Epoch 161/400, Cost = 0.535964, Training Accuracy = 0.743849, Validation Accuracy = 0.714286
# Epoch 162/400, Cost = 0.535739, Training Accuracy = 0.745297, Validation Accuracy = 0.714286
# Epoch 163/400, Cost = 0.535498, Training Accuracy = 0.745297, Validation Accuracy = 0.727273
# Epoch 164/400, Cost = 0.535228, Training Accuracy = 0.748191, Validation Accuracy = 0.727273
# Epoch 165/400, Cost = 0.534966, Training Accuracy = 0.748191, Validation Accuracy = 0.727273
# Epoch 166/400, Cost = 0.534711, Training Accuracy = 0.748191, Validation Accuracy = 0.727273
# Epoch 167/400, Cost = 0.534460, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 168/400, Cost = 0.534211, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 169/400, Cost = 0.533963, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 170/400, Cost = 0.533717, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 171/400, Cost = 0.533475, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 172/400, Cost = 0.533234, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 173/400, Cost = 0.532996, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 174/400, Cost = 0.532760, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 175/400, Cost = 0.532526, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 176/400, Cost = 0.532294, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 177/400, Cost = 0.532065, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 178/400, Cost = 0.531839, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 179/400, Cost = 0.531614, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 180/400, Cost = 0.531380, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 181/400, Cost = 0.531146, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 182/400, Cost = 0.530918, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 183/400, Cost = 0.530692, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 184/400, Cost = 0.530469, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 185/400, Cost = 0.530230, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 186/400, Cost = 0.529997, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 187/400, Cost = 0.529765, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 188/400, Cost = 0.529528, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 189/400, Cost = 0.529297, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 190/400, Cost = 0.529069, Training Accuracy = 0.749638, Validation Accuracy = 0.727273
# Epoch 191/400, Cost = 0.528844, Training Accuracy = 0.749638, Validation Accuracy = 0.740260
# Epoch 192/400, Cost = 0.528622, Training Accuracy = 0.749638, Validation Accuracy = 0.740260
# Epoch 193/400, Cost = 0.528403, Training Accuracy = 0.751085, Validation Accuracy = 0.740260
# Epoch 194/400, Cost = 0.528186, Training Accuracy = 0.751085, Validation Accuracy = 0.740260
# Epoch 195/400, Cost = 0.527972, Training Accuracy = 0.753980, Validation Accuracy = 0.740260
# Epoch 196/400, Cost = 0.527760, Training Accuracy = 0.753980, Validation Accuracy = 0.740260
# Epoch 197/400, Cost = 0.527550, Training Accuracy = 0.753980, Validation Accuracy = 0.740260
# Epoch 198/400, Cost = 0.527343, Training Accuracy = 0.753980, Validation Accuracy = 0.740260
# Epoch 199/400, Cost = 0.527138, Training Accuracy = 0.753980, Validation Accuracy = 0.740260
# Epoch 200/400, Cost = 0.526934, Training Accuracy = 0.753980, Validation Accuracy = 0.740260
# Epoch 201/400, Cost = 0.526733, Training Accuracy = 0.753980, Validation Accuracy = 0.740260
# Epoch 202/400, Cost = 0.526534, Training Accuracy = 0.755427, Validation Accuracy = 0.740260
# Epoch 203/400, Cost = 0.526337, Training Accuracy = 0.753980, Validation Accuracy = 0.740260
# Epoch 204/400, Cost = 0.526143, Training Accuracy = 0.753980, Validation Accuracy = 0.727273
# Epoch 205/400, Cost = 0.525950, Training Accuracy = 0.752533, Validation Accuracy = 0.727273
# Epoch 206/400, Cost = 0.525760, Training Accuracy = 0.752533, Validation Accuracy = 0.727273
# Epoch 207/400, Cost = 0.525570, Training Accuracy = 0.752533, Validation Accuracy = 0.727273
# Epoch 208/400, Cost = 0.525382, Training Accuracy = 0.752533, Validation Accuracy = 0.727273
# Epoch 209/400, Cost = 0.525189, Training Accuracy = 0.752533, Validation Accuracy = 0.727273
# Epoch 210/400, Cost = 0.524983, Training Accuracy = 0.753980, Validation Accuracy = 0.727273
# Epoch 211/400, Cost = 0.524782, Training Accuracy = 0.753980, Validation Accuracy = 0.727273
# Epoch 212/400, Cost = 0.524583, Training Accuracy = 0.753980, Validation Accuracy = 0.727273
# Epoch 213/400, Cost = 0.524386, Training Accuracy = 0.753980, Validation Accuracy = 0.727273
# Epoch 214/400, Cost = 0.524190, Training Accuracy = 0.753980, Validation Accuracy = 0.727273
# Epoch 215/400, Cost = 0.523984, Training Accuracy = 0.753980, Validation Accuracy = 0.727273
# Epoch 216/400, Cost = 0.523768, Training Accuracy = 0.752533, Validation Accuracy = 0.727273
# Epoch 217/400, Cost = 0.523556, Training Accuracy = 0.753980, Validation Accuracy = 0.727273
# Epoch 218/400, Cost = 0.523348, Training Accuracy = 0.753980, Validation Accuracy = 0.727273
# Epoch 219/400, Cost = 0.523144, Training Accuracy = 0.753980, Validation Accuracy = 0.727273
# Epoch 220/400, Cost = 0.522942, Training Accuracy = 0.753980, Validation Accuracy = 0.727273
# Epoch 221/400, Cost = 0.522737, Training Accuracy = 0.753980, Validation Accuracy = 0.727273
# Epoch 222/400, Cost = 0.522512, Training Accuracy = 0.752533, Validation Accuracy = 0.727273
# Epoch 223/400, Cost = 0.522277, Training Accuracy = 0.751085, Validation Accuracy = 0.727273
# Epoch 224/400, Cost = 0.522044, Training Accuracy = 0.751085, Validation Accuracy = 0.740260
# Epoch 225/400, Cost = 0.521811, Training Accuracy = 0.752533, Validation Accuracy = 0.740260
# Epoch 226/400, Cost = 0.521579, Training Accuracy = 0.753980, Validation Accuracy = 0.740260
# Epoch 227/400, Cost = 0.521354, Training Accuracy = 0.753980, Validation Accuracy = 0.740260
# Epoch 228/400, Cost = 0.521132, Training Accuracy = 0.752533, Validation Accuracy = 0.740260
# Epoch 229/400, Cost = 0.520911, Training Accuracy = 0.751085, Validation Accuracy = 0.740260
# Epoch 230/400, Cost = 0.520691, Training Accuracy = 0.751085, Validation Accuracy = 0.740260
# Epoch 231/400, Cost = 0.520474, Training Accuracy = 0.752533, Validation Accuracy = 0.740260
# Epoch 232/400, Cost = 0.520259, Training Accuracy = 0.751085, Validation Accuracy = 0.740260
# Epoch 233/400, Cost = 0.520047, Training Accuracy = 0.751085, Validation Accuracy = 0.740260
# Epoch 234/400, Cost = 0.519818, Training Accuracy = 0.751085, Validation Accuracy = 0.740260
# Epoch 235/400, Cost = 0.519592, Training Accuracy = 0.751085, Validation Accuracy = 0.740260
# Epoch 236/400, Cost = 0.519368, Training Accuracy = 0.752533, Validation Accuracy = 0.740260
# Epoch 237/400, Cost = 0.519147, Training Accuracy = 0.752533, Validation Accuracy = 0.740260
# Epoch 238/400, Cost = 0.518930, Training Accuracy = 0.752533, Validation Accuracy = 0.740260
# Epoch 239/400, Cost = 0.518714, Training Accuracy = 0.752533, Validation Accuracy = 0.740260
# Epoch 240/400, Cost = 0.518500, Training Accuracy = 0.753980, Validation Accuracy = 0.740260
# Epoch 241/400, Cost = 0.518288, Training Accuracy = 0.753980, Validation Accuracy = 0.740260
# Epoch 242/400, Cost = 0.518077, Training Accuracy = 0.753980, Validation Accuracy = 0.740260
# Epoch 243/400, Cost = 0.517867, Training Accuracy = 0.753980, Validation Accuracy = 0.753247
# Epoch 244/400, Cost = 0.517660, Training Accuracy = 0.753980, Validation Accuracy = 0.753247
# Epoch 245/400, Cost = 0.517453, Training Accuracy = 0.753980, Validation Accuracy = 0.753247
# Epoch 246/400, Cost = 0.517248, Training Accuracy = 0.753980, Validation Accuracy = 0.753247
# Epoch 247/400, Cost = 0.517042, Training Accuracy = 0.753980, Validation Accuracy = 0.753247
# Epoch 248/400, Cost = 0.516836, Training Accuracy = 0.753980, Validation Accuracy = 0.753247
# Epoch 249/400, Cost = 0.516632, Training Accuracy = 0.755427, Validation Accuracy = 0.753247
# Epoch 250/400, Cost = 0.516429, Training Accuracy = 0.755427, Validation Accuracy = 0.753247
# Epoch 251/400, Cost = 0.516228, Training Accuracy = 0.756874, Validation Accuracy = 0.753247
# Epoch 252/400, Cost = 0.516029, Training Accuracy = 0.756874, Validation Accuracy = 0.753247
# Epoch 253/400, Cost = 0.515833, Training Accuracy = 0.756874, Validation Accuracy = 0.753247
# Epoch 254/400, Cost = 0.515642, Training Accuracy = 0.756874, Validation Accuracy = 0.753247
# Epoch 255/400, Cost = 0.515451, Training Accuracy = 0.756874, Validation Accuracy = 0.753247
# Epoch 256/400, Cost = 0.515262, Training Accuracy = 0.756874, Validation Accuracy = 0.753247
# Epoch 257/400, Cost = 0.515074, Training Accuracy = 0.756874, Validation Accuracy = 0.753247
# Epoch 258/400, Cost = 0.514888, Training Accuracy = 0.756874, Validation Accuracy = 0.753247
# Epoch 259/400, Cost = 0.514704, Training Accuracy = 0.756874, Validation Accuracy = 0.753247
# Epoch 260/400, Cost = 0.514522, Training Accuracy = 0.756874, Validation Accuracy = 0.753247
# Epoch 261/400, Cost = 0.514342, Training Accuracy = 0.756874, Validation Accuracy = 0.753247
# Epoch 262/400, Cost = 0.514163, Training Accuracy = 0.758321, Validation Accuracy = 0.753247
# Epoch 263/400, Cost = 0.513985, Training Accuracy = 0.759768, Validation Accuracy = 0.753247
# Epoch 264/400, Cost = 0.513809, Training Accuracy = 0.758321, Validation Accuracy = 0.753247
# Epoch 265/400, Cost = 0.513633, Training Accuracy = 0.758321, Validation Accuracy = 0.753247
# Epoch 266/400, Cost = 0.513458, Training Accuracy = 0.758321, Validation Accuracy = 0.753247
# Epoch 267/400, Cost = 0.513283, Training Accuracy = 0.758321, Validation Accuracy = 0.753247
# Epoch 268/400, Cost = 0.513108, Training Accuracy = 0.759768, Validation Accuracy = 0.753247
# Epoch 269/400, Cost = 0.512935, Training Accuracy = 0.759768, Validation Accuracy = 0.753247
# Epoch 270/400, Cost = 0.512763, Training Accuracy = 0.759768, Validation Accuracy = 0.753247
# Epoch 271/400, Cost = 0.512592, Training Accuracy = 0.759768, Validation Accuracy = 0.753247
# Epoch 272/400, Cost = 0.512421, Training Accuracy = 0.759768, Validation Accuracy = 0.753247
# Epoch 273/400, Cost = 0.512252, Training Accuracy = 0.759768, Validation Accuracy = 0.753247
# Epoch 274/400, Cost = 0.512082, Training Accuracy = 0.759768, Validation Accuracy = 0.753247
# Epoch 275/400, Cost = 0.511912, Training Accuracy = 0.761216, Validation Accuracy = 0.753247
# Epoch 276/400, Cost = 0.511743, Training Accuracy = 0.761216, Validation Accuracy = 0.753247
# Epoch 277/400, Cost = 0.511576, Training Accuracy = 0.761216, Validation Accuracy = 0.753247
# Epoch 278/400, Cost = 0.511409, Training Accuracy = 0.761216, Validation Accuracy = 0.753247
# Epoch 279/400, Cost = 0.511244, Training Accuracy = 0.762663, Validation Accuracy = 0.753247
# Epoch 280/400, Cost = 0.511080, Training Accuracy = 0.762663, Validation Accuracy = 0.753247
# Epoch 281/400, Cost = 0.510918, Training Accuracy = 0.762663, Validation Accuracy = 0.753247
# Epoch 282/400, Cost = 0.510757, Training Accuracy = 0.762663, Validation Accuracy = 0.753247
# Epoch 283/400, Cost = 0.510597, Training Accuracy = 0.762663, Validation Accuracy = 0.753247
# Epoch 284/400, Cost = 0.510436, Training Accuracy = 0.762663, Validation Accuracy = 0.753247
# Epoch 285/400, Cost = 0.510275, Training Accuracy = 0.761216, Validation Accuracy = 0.753247
# Epoch 286/400, Cost = 0.510114, Training Accuracy = 0.761216, Validation Accuracy = 0.753247
# Epoch 287/400, Cost = 0.509954, Training Accuracy = 0.761216, Validation Accuracy = 0.753247
# Epoch 288/400, Cost = 0.509795, Training Accuracy = 0.761216, Validation Accuracy = 0.753247
# Epoch 289/400, Cost = 0.509637, Training Accuracy = 0.759768, Validation Accuracy = 0.740260
# Epoch 290/400, Cost = 0.509477, Training Accuracy = 0.759768, Validation Accuracy = 0.740260
# Epoch 291/400, Cost = 0.509308, Training Accuracy = 0.761216, Validation Accuracy = 0.740260
# Epoch 292/400, Cost = 0.509142, Training Accuracy = 0.759768, Validation Accuracy = 0.740260
# Epoch 293/400, Cost = 0.508975, Training Accuracy = 0.759768, Validation Accuracy = 0.740260
# Epoch 294/400, Cost = 0.508807, Training Accuracy = 0.759768, Validation Accuracy = 0.740260
# Epoch 295/400, Cost = 0.508640, Training Accuracy = 0.759768, Validation Accuracy = 0.740260
# Epoch 296/400, Cost = 0.508475, Training Accuracy = 0.761216, Validation Accuracy = 0.740260
# Epoch 297/400, Cost = 0.508310, Training Accuracy = 0.761216, Validation Accuracy = 0.740260
# Epoch 298/400, Cost = 0.508146, Training Accuracy = 0.762663, Validation Accuracy = 0.740260
# Epoch 299/400, Cost = 0.507981, Training Accuracy = 0.762663, Validation Accuracy = 0.740260
# Epoch 300/400, Cost = 0.507813, Training Accuracy = 0.762663, Validation Accuracy = 0.740260
# Epoch 301/400, Cost = 0.507649, Training Accuracy = 0.762663, Validation Accuracy = 0.740260
# Epoch 302/400, Cost = 0.507485, Training Accuracy = 0.762663, Validation Accuracy = 0.740260
# Epoch 303/400, Cost = 0.507322, Training Accuracy = 0.762663, Validation Accuracy = 0.740260
# Epoch 304/400, Cost = 0.507160, Training Accuracy = 0.762663, Validation Accuracy = 0.740260
# Epoch 305/400, Cost = 0.507000, Training Accuracy = 0.762663, Validation Accuracy = 0.740260
# Epoch 306/400, Cost = 0.506840, Training Accuracy = 0.762663, Validation Accuracy = 0.740260
# Epoch 307/400, Cost = 0.506680, Training Accuracy = 0.761216, Validation Accuracy = 0.740260
# Epoch 308/400, Cost = 0.506518, Training Accuracy = 0.761216, Validation Accuracy = 0.740260
# Epoch 309/400, Cost = 0.506355, Training Accuracy = 0.759768, Validation Accuracy = 0.740260
# Epoch 310/400, Cost = 0.506189, Training Accuracy = 0.761216, Validation Accuracy = 0.740260
# Epoch 311/400, Cost = 0.506029, Training Accuracy = 0.761216, Validation Accuracy = 0.740260
# Epoch 312/400, Cost = 0.505869, Training Accuracy = 0.761216, Validation Accuracy = 0.740260
# Epoch 313/400, Cost = 0.505711, Training Accuracy = 0.761216, Validation Accuracy = 0.740260
# Epoch 314/400, Cost = 0.505554, Training Accuracy = 0.761216, Validation Accuracy = 0.740260
# Epoch 315/400, Cost = 0.505395, Training Accuracy = 0.761216, Validation Accuracy = 0.740260
# Epoch 316/400, Cost = 0.505238, Training Accuracy = 0.761216, Validation Accuracy = 0.740260
# Epoch 317/400, Cost = 0.505082, Training Accuracy = 0.761216, Validation Accuracy = 0.740260
# Epoch 318/400, Cost = 0.504913, Training Accuracy = 0.761216, Validation Accuracy = 0.740260
# Epoch 319/400, Cost = 0.504747, Training Accuracy = 0.761216, Validation Accuracy = 0.740260
# Epoch 320/400, Cost = 0.504580, Training Accuracy = 0.761216, Validation Accuracy = 0.740260
# Epoch 321/400, Cost = 0.504415, Training Accuracy = 0.761216, Validation Accuracy = 0.740260
# Epoch 322/400, Cost = 0.504242, Training Accuracy = 0.761216, Validation Accuracy = 0.740260
# Epoch 323/400, Cost = 0.504058, Training Accuracy = 0.758321, Validation Accuracy = 0.740260
# Epoch 324/400, Cost = 0.503877, Training Accuracy = 0.758321, Validation Accuracy = 0.740260
# Epoch 325/400, Cost = 0.503698, Training Accuracy = 0.758321, Validation Accuracy = 0.740260
# Epoch 326/400, Cost = 0.503519, Training Accuracy = 0.758321, Validation Accuracy = 0.740260
# Epoch 327/400, Cost = 0.503342, Training Accuracy = 0.759768, Validation Accuracy = 0.740260
# Epoch 328/400, Cost = 0.503166, Training Accuracy = 0.759768, Validation Accuracy = 0.740260
# Epoch 329/400, Cost = 0.502994, Training Accuracy = 0.759768, Validation Accuracy = 0.740260
# Epoch 330/400, Cost = 0.502823, Training Accuracy = 0.758321, Validation Accuracy = 0.740260
# Epoch 331/400, Cost = 0.502654, Training Accuracy = 0.758321, Validation Accuracy = 0.740260
# Epoch 332/400, Cost = 0.502485, Training Accuracy = 0.758321, Validation Accuracy = 0.740260
# Epoch 333/400, Cost = 0.502318, Training Accuracy = 0.758321, Validation Accuracy = 0.740260
# Epoch 334/400, Cost = 0.502152, Training Accuracy = 0.756874, Validation Accuracy = 0.740260
# Epoch 335/400, Cost = 0.501988, Training Accuracy = 0.755427, Validation Accuracy = 0.740260
# Epoch 336/400, Cost = 0.501825, Training Accuracy = 0.755427, Validation Accuracy = 0.740260
# Epoch 337/400, Cost = 0.501663, Training Accuracy = 0.755427, Validation Accuracy = 0.740260
# Epoch 338/400, Cost = 0.501499, Training Accuracy = 0.755427, Validation Accuracy = 0.740260
# Epoch 339/400, Cost = 0.501336, Training Accuracy = 0.755427, Validation Accuracy = 0.740260
# Epoch 340/400, Cost = 0.501174, Training Accuracy = 0.755427, Validation Accuracy = 0.727273
# Epoch 341/400, Cost = 0.501013, Training Accuracy = 0.755427, Validation Accuracy = 0.727273
# Epoch 342/400, Cost = 0.500850, Training Accuracy = 0.753980, Validation Accuracy = 0.714286
# Epoch 343/400, Cost = 0.500688, Training Accuracy = 0.753980, Validation Accuracy = 0.714286
# Epoch 344/400, Cost = 0.500527, Training Accuracy = 0.753980, Validation Accuracy = 0.714286
# Epoch 345/400, Cost = 0.500364, Training Accuracy = 0.753980, Validation Accuracy = 0.714286
# Epoch 346/400, Cost = 0.500189, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 347/400, Cost = 0.500020, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 348/400, Cost = 0.499851, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 349/400, Cost = 0.499685, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 350/400, Cost = 0.499519, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 351/400, Cost = 0.499356, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 352/400, Cost = 0.499194, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 353/400, Cost = 0.499030, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 354/400, Cost = 0.498854, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 355/400, Cost = 0.498681, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 356/400, Cost = 0.498508, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 357/400, Cost = 0.498335, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 358/400, Cost = 0.498163, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 359/400, Cost = 0.497975, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 360/400, Cost = 0.497791, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 361/400, Cost = 0.497589, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 362/400, Cost = 0.497391, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 363/400, Cost = 0.497194, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 364/400, Cost = 0.497001, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 365/400, Cost = 0.496812, Training Accuracy = 0.756874, Validation Accuracy = 0.714286
# Epoch 366/400, Cost = 0.496623, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 367/400, Cost = 0.496439, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 368/400, Cost = 0.496256, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 369/400, Cost = 0.496073, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 370/400, Cost = 0.495889, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 371/400, Cost = 0.495707, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 372/400, Cost = 0.495525, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 373/400, Cost = 0.495344, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 374/400, Cost = 0.495166, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 375/400, Cost = 0.494989, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 376/400, Cost = 0.494815, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 377/400, Cost = 0.494641, Training Accuracy = 0.758321, Validation Accuracy = 0.727273
# Epoch 378/400, Cost = 0.494469, Training Accuracy = 0.758321, Validation Accuracy = 0.727273
# Epoch 379/400, Cost = 0.494301, Training Accuracy = 0.758321, Validation Accuracy = 0.727273
# Epoch 380/400, Cost = 0.494137, Training Accuracy = 0.758321, Validation Accuracy = 0.727273
# Epoch 381/400, Cost = 0.493974, Training Accuracy = 0.758321, Validation Accuracy = 0.727273
# Epoch 382/400, Cost = 0.493810, Training Accuracy = 0.758321, Validation Accuracy = 0.714286
# Epoch 383/400, Cost = 0.493646, Training Accuracy = 0.758321, Validation Accuracy = 0.701299
# Epoch 384/400, Cost = 0.493484, Training Accuracy = 0.758321, Validation Accuracy = 0.701299
# Epoch 385/400, Cost = 0.493323, Training Accuracy = 0.758321, Validation Accuracy = 0.701299
# Epoch 386/400, Cost = 0.493165, Training Accuracy = 0.758321, Validation Accuracy = 0.701299
# Epoch 387/400, Cost = 0.493009, Training Accuracy = 0.758321, Validation Accuracy = 0.701299
# Epoch 388/400, Cost = 0.492857, Training Accuracy = 0.758321, Validation Accuracy = 0.701299
# Epoch 389/400, Cost = 0.492704, Training Accuracy = 0.758321, Validation Accuracy = 0.701299
# Epoch 390/400, Cost = 0.492552, Training Accuracy = 0.758321, Validation Accuracy = 0.701299
# Epoch 391/400, Cost = 0.492400, Training Accuracy = 0.758321, Validation Accuracy = 0.701299
# Epoch 392/400, Cost = 0.492249, Training Accuracy = 0.758321, Validation Accuracy = 0.701299
# Epoch 393/400, Cost = 0.492101, Training Accuracy = 0.758321, Validation Accuracy = 0.701299
# Epoch 394/400, Cost = 0.491954, Training Accuracy = 0.758321, Validation Accuracy = 0.701299
# Epoch 395/400, Cost = 0.491807, Training Accuracy = 0.758321, Validation Accuracy = 0.701299
# Epoch 396/400, Cost = 0.491663, Training Accuracy = 0.759768, Validation Accuracy = 0.701299
# Epoch 397/400, Cost = 0.491520, Training Accuracy = 0.759768, Validation Accuracy = 0.701299
# Epoch 398/400, Cost = 0.491378, Training Accuracy = 0.759768, Validation Accuracy = 0.701299
# Epoch 399/400, Cost = 0.491237, Training Accuracy = 0.759768, Validation Accuracy = 0.701299
# Epoch 400/400, Cost = 0.491097, Training Accuracy = 0.759768, Validation Accuracy = 0.701299
# Epoch 400/400, Cost = 0.491097, Training Accuracy = 0.759768, Validation Accuracy = 0.701299

# %%
# import pandas as pd
# import numpy as np

# import matplotlib.pyplot as plt
# import seaborn as sns
# %matplotlib inline

# data = pd.read_csv('./dataR2 (copy).csv')

# inputs = data.drop('Classification', axis = 1)
# inputs = np.array(inputs)

# from sklearn.preprocessing import StandardScaler, MinMaxScaler
# sc = MinMaxScaler()
# inputs = sc.fit_transform(inputs)
# outputs = data['Classification'].as_matrix()

# from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(inputs, outputs, test_size=0.10, random_state=42)

# plt.rcParams['figure.figsize'] = (15.0, 12.0) # set default size of plots
# plt.rcParams['image.interpolation'] = 'nearest'
# plt.rcParams['image.cmap'] = 'gray'

# %%
# np.random.seed(10)
# net2 = Neural_Net([10,5])
# costs = net2.train(X_train,y_train,X_test,y_test,epochs=400,learning_rate=0.05,printCost=True,printEvery=1)

# %%
# import pandas as pd
# import numpy as np

# import matplotlib.pyplot as plt
# import seaborn as sns
# %matplotlib inline

# data = pd.read_csv('./SomeRandomPaperDataset.csv')
# data = np.array(data.as_matrix()).T
# data = pd.DataFrame(data)
# lst = data.columns

# inputs = data.drop([45033], axis = 1)
# inputs = np.array(inputs)

# from sklearn.preprocessing import StandardScaler, MinMaxScaler
# sc = MinMaxScaler()
# inputs = sc.fit_transform(inputs)
# outputs = data[45033].as_matrix()

# from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(inputs, outputs, test_size=0.10, random_state=301)

# plt.rcParams['figure.figsize'] = (15.0, 12.0) # set default size of plots
# plt.rcParams['image.interpolation'] = 'nearest'
# plt.rcParams['image.cmap'] = 'gray'

# %%
# X_train.shape

# %%
# np.random.seed(10)
# net3 = Neural_Net([45,45,45,45])
# costs = net3.train(X_train,y_train,X_test,y_test,epochs=100,learning_rate=0.1,printCost=True,printEvery=1)
